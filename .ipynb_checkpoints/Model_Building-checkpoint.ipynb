# %%
import pandas as pd

# %%
meds = pd.read_csv('meds_cleaned_v1')

# %%
meds
# Out:
#       Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar  CK-MB  \
# 0      63       1          66          160            83        160.0   1.80
# 1      20       1          94           98            46        296.0   6.75
# 2      56       1          64          160            77        270.0   1.99
# 3      66       1          70          120            55        270.0  13.87
# 4      54       1          64          112            65        300.0   1.08
# ...   ...     ...         ...          ...           ...          ...    ...
# 1240   44       1          94          122            67        204.0   1.63
# 1241   66       1          84          125            55        149.0   1.33
# 1242   45       1          85          168           104         96.0   1.24
# 1243   54       1          58          117            68        443.0   5.80
# 1244   51       1          94          157            79        134.0  50.89
#
#       Troponin    Result
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1240     0.006  negative
# 1241     0.172  positive
# 1242     4.250  positive
# 1243     0.359  positive
# 1244     1.770  positive
#
# [1245 rows x 9 columns]

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in d:\projects\heart_disease_classification\heartenv\lib\site-packages (3.3.0)
# Requirement already satisfied: ipython>=5.5.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (8.23.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (8.1.2)
# Requirement already satisfied: tqdm>=4.62.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (4.66.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (3.1.3)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (1.4.0)
# Requirement already satisfied: scikit-learn>1.4.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: category-encoders>=2.4.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.59.1)
# Requirement already satisfied: requests>=2.27.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (5.9.8)
# Requirement already satisfied: markupsafe>=2.0.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (7.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: matplotlib<3.8.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (5.20.0)
# Requirement already satisfied: kaleido>=0.2.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: sktime>=0.26.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (0.28.0)
# Requirement already satisfied: tbats>=1.1.3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: patsy>=0.5.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: packaging in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from deprecation>=2.1.0->pycaret) (24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.4.0)
# Requirement already satisfied: zipp>=0.5 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.18.1)
# Requirement already satisfied: decorator in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (2.17.2)
# Requirement already satisfied: stack-data in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.2)
# Requirement already satisfied: typing-extensions in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (4.11.0)
# Requirement already satisfied: colorama in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from numba>=0.55.0->pycaret) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.3)
# Requirement already satisfied: dash>=2.9.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.16.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.10)
# Requirement already satisfied: urllib3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (65.5.0)
# Requirement already satisfied: six in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from pyod>=1.1.3->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from requests>=2.27.1->pycaret) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from requests>=2.27.1->pycaret) (2024.2.2)
# Requirement already satisfied: scikit-base<0.8.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from sktime>=0.26.0->pycaret) (0.7.5)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.2)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.2.0)
# Requirement already satisfied: pywin32>=300 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (306)
# Requirement already satisfied: wcwidth in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in d:\projects\heart_disease_classification\heartenv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.7.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pycaret.classification import ClassificationExperiment

# %%
s = ClassificationExperiment()
s.setup(data = meds, target = 'Result', transformation = True,
        remove_multicollinearity = True, normalize = True)
# Out:
# <style type="text/css">
# #T_417ff_row9_col1, #T_417ff_row13_col1, #T_417ff_row15_col1, #T_417ff_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_417ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_417ff_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_417ff_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_417ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_417ff_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_417ff_row0_col1" class="data row0 col1" >6770</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_417ff_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_417ff_row1_col1" class="data row1 col1" >Result</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_417ff_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_417ff_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_417ff_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_417ff_row3_col1" class="data row3 col1" >negative: 0, positive: 1</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_417ff_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_417ff_row4_col1" class="data row4 col1" >(1245, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_417ff_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_417ff_row5_col1" class="data row5 col1" >(1245, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_417ff_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_417ff_row6_col1" class="data row6 col1" >(871, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_417ff_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_417ff_row7_col1" class="data row7 col1" >(374, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_417ff_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_417ff_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_417ff_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_417ff_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_417ff_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_417ff_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_417ff_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_417ff_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_417ff_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_417ff_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_417ff_row13_col0" class="data row13 col0" >Remove multicollinearity</td>
#       <td id="T_417ff_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_417ff_row14_col0" class="data row14 col0" >Multicollinearity threshold</td>
#       <td id="T_417ff_row14_col1" class="data row14 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_417ff_row15_col0" class="data row15 col0" >Transformation</td>
#       <td id="T_417ff_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_417ff_row16_col0" class="data row16 col0" >Transformation method</td>
#       <td id="T_417ff_row16_col1" class="data row16 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_417ff_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_417ff_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_417ff_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_417ff_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_417ff_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_417ff_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_417ff_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_417ff_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_417ff_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_417ff_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_417ff_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_417ff_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_417ff_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_417ff_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_417ff_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_417ff_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_417ff_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_417ff_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_417ff_row25_col1" class="data row25 col1" >ff71</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.compare_models()
# Out:
# <style type="text/css">
# #T_4cf78 th {
#   text-align: left;
# }
# #T_4cf78_row0_col0, #T_4cf78_row1_col0, #T_4cf78_row1_col2, #T_4cf78_row1_col4, #T_4cf78_row1_col6, #T_4cf78_row1_col7, #T_4cf78_row2_col0, #T_4cf78_row2_col1, #T_4cf78_row2_col2, #T_4cf78_row2_col3, #T_4cf78_row2_col4, #T_4cf78_row2_col5, #T_4cf78_row2_col6, #T_4cf78_row2_col7, #T_4cf78_row3_col0, #T_4cf78_row3_col1, #T_4cf78_row3_col2, #T_4cf78_row3_col3, #T_4cf78_row3_col4, #T_4cf78_row3_col5, #T_4cf78_row3_col6, #T_4cf78_row3_col7, #T_4cf78_row4_col0, #T_4cf78_row4_col1, #T_4cf78_row4_col2, #T_4cf78_row4_col3, #T_4cf78_row4_col4, #T_4cf78_row4_col5, #T_4cf78_row4_col6, #T_4cf78_row4_col7, #T_4cf78_row5_col0, #T_4cf78_row5_col1, #T_4cf78_row5_col2, #T_4cf78_row5_col3, #T_4cf78_row5_col4, #T_4cf78_row5_col5, #T_4cf78_row5_col6, #T_4cf78_row5_col7, #T_4cf78_row6_col0, #T_4cf78_row6_col1, #T_4cf78_row6_col2, #T_4cf78_row6_col3, #T_4cf78_row6_col4, #T_4cf78_row6_col5, #T_4cf78_row6_col6, #T_4cf78_row6_col7, #T_4cf78_row7_col0, #T_4cf78_row7_col1, #T_4cf78_row7_col2, #T_4cf78_row7_col3, #T_4cf78_row7_col4, #T_4cf78_row7_col5, #T_4cf78_row7_col6, #T_4cf78_row7_col7, #T_4cf78_row8_col0, #T_4cf78_row8_col1, #T_4cf78_row8_col2, #T_4cf78_row8_col3, #T_4cf78_row8_col4, #T_4cf78_row8_col5, #T_4cf78_row8_col6, #T_4cf78_row8_col7, #T_4cf78_row9_col0, #T_4cf78_row9_col1, #T_4cf78_row9_col2, #T_4cf78_row9_col3, #T_4cf78_row9_col4, #T_4cf78_row9_col5, #T_4cf78_row9_col6, #T_4cf78_row9_col7, #T_4cf78_row10_col0, #T_4cf78_row10_col1, #T_4cf78_row10_col2, #T_4cf78_row10_col3, #T_4cf78_row10_col4, #T_4cf78_row10_col5, #T_4cf78_row10_col6, #T_4cf78_row10_col7, #T_4cf78_row11_col0, #T_4cf78_row11_col1, #T_4cf78_row11
td>
#     </tr>
#     <tr>
#       <th id="T_96bc9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_96bc9_row7_col0" class="data row7 col0" >0.9885</td>
#       <td id="T_96bc9_row7_col1" class="data row7 col1" >0.9820</td>
#       <td id="T_96bc9_row7_col2" class="data row7 col2" >0.9885</td>
#       <td id="T_96bc9_row7_col3" class="data row7 col3" >0.9888</td>
#       <td id="T_96bc9_row7_col4" class="data row7 col4" >0.9885</td>
#       <td id="T_96bc9_row7_col5" class="data row7 col5" >0.9760</td>
#       <td id="T_96bc9_row7_col6" class="data row7 col6" >0.9763</td>
#     </tr>
#     <tr>
#       <th id="T_96bc9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_96bc9_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_96bc9_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_96bc9_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_96bc9_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_96bc9_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_96bc9_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_96bc9_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_96bc9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_96bc9_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_96bc9_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_96bc9_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_96bc9_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_96bc9_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_96bc9_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_96bc9_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_96bc9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_96bc9_row10_col0" class="data row10 col0" >0.9828</td>
#       <td id="T_96bc9_row10_col1" class="data row10 col1" >0.9951</td>
#       <td id="T_96bc9_row10_col2" class="data row10 col2" >0.9828</td>
#       <td id="T_96bc9_row10_col3" class="data row10 col3" >0.9832</td>
#       <td id="T_96bc9_row10_col4" class="data row10 col4" >0.9828</td>
#       <td id="T_96bc9_row10_col5" class="data row10 col5" >0.9640</td>
#       <td id="T_96bc9_row10_col6" class="data row10 col6" >0.9643</td>
#     </tr>
#     <tr>
#       <th id="T_96bc9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_96bc9_row11_col0" class="data row11 col0" >0.0118</td>
#       <td id="T_96bc9_row11_col1" class="data row11 col1" >0.0062</td>
#       <td id="T_96bc9_row11_col2" class="data row11 col2" >0.0118</td>
#       <td id="T_96bc9_row11_col3" class="data row11 col3" >0.0116</td>
#       <td id="T_96bc9_row11_col4

# %%
s.predict_model(model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_06e80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06e80_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_06e80_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_06e80_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_06e80_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_06e80_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_06e80_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_06e80_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_06e80_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06e80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06e80_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_06e80_row0_col1" class="data row0 col1" >0.9973</td>
#       <td id="T_06e80_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_06e80_row0_col3" class="data row0 col3" >0.9973</td>
#       <td id="T_06e80_row0_col4" class="data row0 col4" >0.9973</td>
#       <td id="T_06e80_row0_col5" class="data row0 col5" >0.9973</td>
#       <td id="T_06e80_row0_col6" class="data row0 col6" >0.9944</td>
#       <td id="T_06e80_row0_col7" class="data row0 col7" >0.9944</td>
#     </tr>
#   </tbody>
# </table>
#       Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar  \
# 410    65       1          70          142            75        108.0
# 921    43       0          75          150            95        103.0
# 529    35       1          61          125            80        100.0
# 159    60       0         100          170           103        197.0
# 1176   60       1          64          140            90        230.0
# ...   ...     ...         ...          ...           ...          ...
# 1050   50       1          75          116            71        126.0
# 916    70       1         112          170           104        117.0
# 68     54       0          58          130            80        125.0
# 1170   37       1          78           95            59        107.0
# 1073   70       1          76          136            82        233.0
#
#            CK-MB  Troponin    Result prediction_label  prediction_score
# 410   165.000000     0.058  positive         positive              1.00
# 921    81.839996     0.005  positive         positive              0.90
# 529     7.660000     0.003  positive         positive              0.90
# 159     3.360000     0.012  negative         negative              0.93
# 1176    1.250000     0.009  negative         negative              0.94
# ...          ...       ...       ...              ...               ...
# 1050    2.240000     0.053  positive         positive              0.99
# 916     3.950000     0.012  negative         negative              0.76
# 68      3.300000     0.006  negative         negative              0.94
# 1170   39.340000     0.022  positive         positive              1.00
# 1073    2.560000     2.160  positive         positive              0.97
#
# [374 rows x 11 columns]

# %%
cols = meds.columns.to_list()

# %%
cols.pop()
# Out:
# 'Result'

# %%
cols
# Out:
# ['Age',
#  'Gender',
#  'Heart rate',
#  'Systolic bp',
#  'Diastolic bp',
#  'Blood sugar',
#  'CK-MB',
#  'Troponin']

# %%
new = [50, 0,89, 100, 50, 92.0, 16.950001, 0.023]

# %%
unseen = pd.DataFrame([new], columns=cols)

# %%
s.predict_model(model, data = unseen)
# Out:
#    Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar      CK-MB  \
# 0   50       0          89          100            50         92.0  16.950001
#
#    Troponin prediction_label  prediction_score
# 0     0.023         positive              0.96

# %%
s.plot_model(model, plot = 'error')

# %%
s.plot_model(model, plot = 'class_report')

# %%
s.plot_model(model, plot = 'pr')

# %%
s.plot_model(model, plot = 'confusion_matrix')

# %%
s.plot_model(model, plot = 'feature')

# %%
meds
# Out:
#       Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar  CK-MB  \
# 0      63       1          66          160            83        160.0   1.80
# 1      20       1          94           98            46        296.0   6.75
# 2      56       1          64          160            77        270.0   1.99
# 3      66       1          70          120            55        270.0  13.87
# 4      54       1          64          112            65        300.0   1.08
# ...   ...     ...         ...          ...           ...          ...    ...
# 1240   44       1          94          122            67        204.0   1.63
# 1241   66       1          84          125            55        149.0   1.33
# 1242   45       1          85          168           104         96.0   1.24
# 1243   54       1          58          117            68        443.0   5.80
# 1244   51       1          94          157            79        134.0  50.89
#
#       Troponin    Result
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# 3        0.122  positive
# 4        0.003  negative
# ...        ...       ...
# 1240     0.006  negative
# 1241     0.172  positive
# 1242     4.250  positive
# 1243     0.359  positive
# 1244     1.770  positive
#
# [1245 rows x 9 columns]

# %%
import numpy as np
num_rows = 10

# Generate random values for each column
age = np.random.randint(20, 80, size=num_rows)
gender = np.random.choice([0, 1], size=num_rows)
heart_rate = np.random.randint(60, 120, size=num_rows)
systolic_bp = np.random.randint(90, 140, size=num_rows)
diastolic_bp = np.random.randint(60, 90, size=num_rows)
blood_sugar = np.random.uniform(70, 120, size=num_rows)
ck_mb = np.random.uniform(5, 25, size=num_rows)
troponin = np.random.uniform(0, 0.1, size=num_rows)

# Create a DataFrame with the generated data
data = pd.DataFrame({
    'Age': age,
    'Gender': gender,
    'Heart rate': heart_rate,
    'Systolic bp': systolic_bp,
    'Diastolic bp': diastolic_bp,
    'Blood sugar': blood_sugar,
    'CK-MB': ck_mb,
    'Troponin': troponin
})

# Display the generated data
data
# Out:
#    Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar      CK-MB  \
# 0   53       1          71          107            69    87.530375   5.069008
# 1   49       1          78          127            73    87.616916  18.356378
# 2   59       1          82          138            71   109.937414  19.768418
# 3   20       1          99          138            61    90.888368   6.299799
# 4   55       0          72           97            87    70.092973   7.835601
# 5   25       1         106          112            85    89.079145  19.812287
# 6   65       0          86          126            74   109.937956  19.246455
# 7   77       1          65          130            83   105.330379   7.832016
# 8   57       1          62          111            80    98.996924  10.433175
# 9   67       1         115           95            82    77.018872  17.370492
#
#    Troponin
# 0  0.018386
# 1  0.090357
# 2  0.048997
# 3  0.036849
# 4  0.066380
# 5  0.052252
# 6  0.012629
# 7  0.069961
# 8  0.032343
# 9  0.037522

# %%
s.predict_model(model, data = data)
# Out:
#    Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar      CK-MB  \
# 0   67       0          91          117            68    70.871696  18.394344
# 1   34       0         119           91            69    74.050575   5.354595
# 2   32       0         119          120            74   117.591866  24.903051
# 3   50       0          83           95            72   114.829910  18.099983
# 4   21       1          70          134            72   118.393539   8.050880
# 5   50       0          79          109            63   101.458221   9.050685
# 6   59       1          60          107            60    80.669823  23.059719
# 7   40       1          82           94            79   112.759041  15.066584
# 8   75       0          60          110            65    75.306534  17.735004
# 9   23       0         108           94            80    93.620697   7.025770
#
#    Troponin prediction_label  prediction_score
# 0  0.053080         positive            1.0000
# 1  0.006180         negative            0.9100
# 2  0.008279         positive            0.9996
# 3  0.065366         positive            1.0000
# 4  0.019981         positive            1.0000
# 5  0.070462         positive            1.0000
# 6  0.043806         positive            1.0000
# 7  0.004520         positive            0.9999
# 8  0.015543         positive            1.0000
# 9  0.054583         positive            0.9985

# %%
s.predict_model(model, data = meds.sample(20))
# Out:
# <style type="text/css">
# </style>
# <table id="T_d117a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d117a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d117a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d117a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d117a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d117a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d117a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d117a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d117a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d117a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d117a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d117a_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_d117a_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_d117a_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_d117a_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_d117a_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_d117a_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_d117a_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
#       Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar  \
# 1216   42       0          70          117            76        100.0
# 1228   43       1          90           95            50        118.0
# 972    64       1          67          120            60        240.0
# 345    90       1          59          164            75        415.0
# 1191   67       1          77          122            58        368.0
# 1208   55       0          73          138            79        105.0
# 254    61       1          59           91            55        103.0
# 243    44       1          71          143            71        104.0
# 543    72       0          83          123            67        283.0
# 0      63       1          66          160            83        160.0
# 855    70       1          63          170           104        144.0
# 122    30       1          85          135            65        105.0
# 48     63       0          81          130            65         98.0
# 670    73       1          83          130            75        108.0
# 1073   70       1          76          136            82        233.0
# 153    32       1          72          136            80        111.0
# 145    50       0          72           91            70        147.0
# 1136   84       0          65          129            75         88.0
# 517    72       0          82          138            82        195.0
# 976    67       0          88          152            87        115.0
#
#           CK-MB  Troponin    Result prediction_label  prediction_score
# 1216   4.240000     0.003  negative         negative            0.9990
# 1228   1.330000     0.544  positive         positive            0.9997
# 972    5.220000     0.009  negative         negative            0.9956
# 345    5.870000     0.014  negative         negative            0.9957
# 1191   2.350000     0.008  negative         negative            0.9998
# 1208   1.610000     0.009  negative         negative            1.0000
# 254    2.940000     0.011  negative         negative            0.9999
# 243    1.190000     0.070  positive         positive            1.0000
# 543    2.120000     0.026  positive         positive            1.0000
# 0      1.800000     0.012  negative         negative            1.0000
# 855    2.410000     0.016  positive         positive            1.0000
# 122    3.250000     0.005  negative         negative            0.9999
# 48     2.280000     0.040  positive         positive            1.0000
# 670    1.630000     0.008  negative         negative            1.0000
# 1073   2.560000     2.160  positive         positive            1.0000
# 153    5.600000     0.003  negative         negative            0.9529
# 145    2.740000     0.063  positive         positive            1.0000
# 1136  31.219999     0.013  positive         positive            0.9998
# 517    1.790000     0.008  negative         negative            1.0000
# 976    2.020000     0.005  negative         negative            1.0000

# %%
s.save_model(model, 'meds_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'Gender', 'Heart rate',
#                                               'Systolic bp', 'Diastolic bp',
#                                               'Blood sugar', 'CK-MB',
#                                               'Troponin'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=Tr...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, n_estimators=100,
#                                          n_jobs=-1, oob_score=False,
#                                          random_state=6770, verbose=0,
#                                          warm_start=False))],
#           verbose=False),
#  'meds_model.pkl')

# %%
model = s.load_model('meds_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
s.predict_model(model, data = meds.sample(20))
# Out:
# <style type="text/css">
# </style>
# <table id="T_51001">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51001_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_51001_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_51001_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_51001_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_51001_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_51001_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_51001_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_51001_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51001_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51001_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_51001_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_51001_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_51001_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_51001_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_51001_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_51001_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_51001_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
#       Age  Gender  Heart rate  Systolic bp  Diastolic bp  Blood sugar  \
# 1094   41       1          89           87            53        140.0
# 855    70       1          63          170           104        144.0
# 1066   60       0          89          111            57        194.0
# 299    21       0          62           76            55        111.0
# 741    64       1          82          138            93         77.0
# 911    47       0          85          138            98        321.0
# 567    82       0          88          152            87         99.0
# 139    44       0          91          100            71        116.0
# 679    60       1          98          110            76         99.0
# 604    72       1          64          112            65        104.0
# 674    60       0          90          125            73        174.0
# 257    38       0          59          100            56         92.0
# 721    66       1          73          115            72        224.0
# 812    65       1          67          177           105        120.0
# 922    60       1          80          127            82        100.0
# 811    41       1          58           93            48        122.0
# 1175   37       1          88          119            66        118.0
# 490    52       1         100          119            66        127.0
# 1119   65       1          84          126            75        382.0
# 182    46       1          69          165            94         95.0
#
#            CK-MB  Troponin    Result prediction_label  prediction_score
# 1094    2.140000     0.003  negative         negative              0.98
# 855     2.410000     0.016  positive         positive              1.00
# 1066    2.170000     0.348  positive         positive              0.96
# 299     3.110000     0.003  negative         negative              0.95
# 741     8.080000     0.021  positive         positive              0.98
# 911     1.880000     0.880  positive         positive              0.97
# 567     1.210000     0.004  negative         negative              0.90
# 139     7.020000     0.014  negative         negative              0.69
# 679     3.170000     0.025  positive         positive              0.99
# 604    23.799999     0.041  positive         positive              1.00
# 674     3.140000     0.006  negative         negative              0.96
# 257    15.670000     0.006  positive         positive              0.98
# 721     3.480000     0.009  negative         negative              0.92
# 812     3.680000     0.011  negative         negative              0.83
# 922   247.800003     0.007  positive         positive              0.98
# 811     3.590000     0.048  positive         positive              0.95
# 1175    5.780000     0.006  negative         negative              0.96
# 490    11.730000     0.018  positive         positive              1.00
# 1119    1.010000     0.018  positive         positive              0.95
# 182     2.820000     0.009  negative         negative              0.91
